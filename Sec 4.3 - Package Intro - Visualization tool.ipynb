# %% [markdown]
# ***
# ## Matplotlib
# ***

# %%
# Requirement
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.path as mpath
import numpy as np
import pandas as pd
import seaborn as sns
import os
from matplotlib.transforms import Affine2D
from mpl_toolkits import mplot3d
from matplotlib.markers import MarkerStyle
from matplotlib.lines import Line2D
from IPython.display import Image

# %%
# Get all available style
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Select Style (optional)
plt.style.use('seaborn-v0_8-whitegrid')

# %%
# Support file type
fig = plt.figure()
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %%
# If folder exist then pass else create a folder called Fig Saver
if os.path.exists('./Fig Saver'):
	print('Folder already exist')
	pass
else:
	print('Folder create')
	os.mkdir('Fig Saver')
# Out:
# Folder create

# %%
# Then we can save the fig to the assign path
path = os.path.join('./Fig Saver','test.png')
plt.figure()
x = np.linspace(0,10,100)
plt.plot(x,np.sin(x))
plt.savefig(path)

# %%
# Read the figure from file
Image(path)

# %% [markdown]
# ***
# ## Matlab-style Interface (PyPlot-style)
# ***

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))
plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

# %% [markdown]
# ***
# ## Objective-oriented interface (OO-style)
# ***

# %%
fig, ax = plt.subplots(2)
ax[0].plot(x,np.sin(x))
ax[1].plot(x,np.cos(x))

# %% [markdown]
# ***
# ## Layout Option
# ***

# %%
plt.figure(figsize = [10,8])
plt.suptitle('Layout option')
opt_layout = ['on','off',
              'square','image',
              'equal','tight']
for k,apt in enumerate(opt_layout,start = 1):
    plt.subplot(3,2,k)
    plt.title(apt)
    plt.plot(x,np.sin(x))
    plt.axis(apt)

# %% [markdown]
# ***
# ## Color
# ***

# %%
# Base color
mcolors.BASE_COLORS
# Out:
# {'b': (0, 0, 1),
#  'g': (0, 0.5, 0),
#  'r': (1, 0, 0),
#  'c': (0, 0.75, 0.75),
#  'm': (0.75, 0, 0.75),
#  'y': (0.75, 0.75, 0),
#  'k': (0, 0, 0),
#  'w': (1, 1, 1)}

# %%
# Tableau color
mcolors.TABLEAU_COLORS
# Out:
# {'tab:blue': '#1f77b4',
#  'tab:orange': '#ff7f0e',
#  'tab:green': '#2ca02c',
#  'tab:red': '#d62728',
#  'tab:purple': '#9467bd',
#  'tab:brown': '#8c564b',
#  'tab:pink': '#e377c2',
#  'tab:gray': '#7f7f7f',
#  'tab:olive': '#bcbd22',
#  'tab:cyan': '#17becf'}

# %%
# HTML color
mcolors.CSS4_COLORS
# Out:
# {'aliceblue': '#F0F8FF',
#  'antiquewhite': '#FAEBD7',
#  'aqua': '#00FFFF',
#  'aquamarine': '#7FFFD4',
#  'azure': '#F0FFFF',
#  'beige': '#F5F5DC',
#  'bisque': '#FFE4C4',
#  'black': '#000000',
#  'blanchedalmond': '#FFEBCD',
#  'blue': '#0000FF',
#  'blueviolet': '#8A2BE2',
#  'brown': '#A52A2A',
#  'burlywood': '#DEB887',
#  'cadetblue': '#5F9EA0',
#  'chartreuse': '#7FFF00',
#  'chocolate': '#D2691E',
#  'coral': '#FF7F50',
#  'cornflowerblue': '#6495ED',
#  'cornsilk': '#FFF8DC',
#  'crimson': '#DC143C',
#  'cyan': '#00FFFF',
#  'darkblue': '#00008B',
#  'darkcyan': '#008B8B',
#  'darkgoldenrod': '#B8860B',
#  'darkgray': '#A9A9A9',
#  'darkgreen': '#006400',
#  'darkgrey': '#A9A9A9',
#  'darkkhaki': '#BDB76B',
#  'darkmagenta': '#8B008B',
#  'darkolivegreen': '#556B2F',
#  'darkorange': '#FF8C00',
#  'darkorchid': '#9932CC',
#  'darkred': '#8B0000',
#  'darksalmon': '#E9967A',
#  'darkseagreen': '#8FBC8F',
#  'darkslateblue': '#483D8B',
#  'darkslategray': '#2F4F4F',
# ...

# %%
# XKCD color
mcolors.XKCD_COLORS
# Out:
# {'xkcd:cloudy blue': '#acc2d9',
#  'xkcd:dark pastel green': '#56ae57',
#  'xkcd:dust': '#b2996e',
#  'xkcd:electric lime': '#a8ff04',
#  'xkcd:fresh green': '#69d84f',
#  'xkcd:light eggplant': '#894585',
#  'xkcd:nasty green': '#70b23f',
#  'xkcd:really light blue': '#d4ffff',
#  'xkcd:tea': '#65ab7c',
#  'xkcd:warm purple': '#952e8f',
#  'xkcd:yellowish tan': '#fcfc81',
#  'xkcd:cement': '#a5a391',
#  'xkcd:dark grass green': '#388004',
#  'xkcd:dusty teal': '#4c9085',
#  'xkcd:grey teal': '#5e9b8a',
#  'xkcd:macaroni and cheese': '#efb435',
#  'xkcd:pinkish tan': '#d99b82',
#  'xkcd:spruce': '#0a5f38',
#  'xkcd:strong blue': '#0c06f7',
#  'xkcd:toxic green': '#61de2a',
#  'xkcd:windows blue': '#3778bf',
#  'xkcd:blue blue': '#2242c7',
#  'xkcd:blue with a hint of purple': '#533cc6',
#  'xkcd:booger': '#9bb53c',
#  'xkcd:bright sea green': '#05ffa6',
#  'xkcd:dark green blue': '#1f6357',
#  'xkcd:deep turquoise': '#017374',
#  'xkcd:green teal': '#0cb577',
# ...

# %%
plt.plot(x,np.sin(x),color = 'blue') # specify color by name
plt.plot(x,np.sin(x - 0.5),color = 'g') # short color code (rgbcmyk)
plt.plot(x,np.sin(x - 1),color = '0.75') # grayscale between 0 ~ 1
plt.plot(x,np.sin(x - 1.5),color = '#FFDD44') # hex code (RRGGBB, 00 to FF)
plt.plot(x,np.sin(x - 2),color = (1,0.2,0.3)) # RGB tuple, values 0 ~ 1
plt.plot(x,np.sin(x - 2.5),color = 'chartreuse'); # HTML color names supported
plt.plot(x,np.sin(x - 3),color = 'xkcd:purple') # XKCD color names supported
plt.plot(x,np.sin(x - 3.5),color = 'tab:orange') # Tableau color names supported

# %% [markdown]
# ***
# ## Named Linestyle
# ***

# %%
# Named Linestyle
plt.plot(x, x + 0,linestyle = 'solid') 
plt.plot(x, x + 1,linestyle = 'dashed') 
plt.plot(x, x + 2,linestyle = 'dashdot') 
plt.plot(x, x + 3,linestyle = 'dotted') 
# For short, you can use the following codes:
plt.plot(x, -x + 0,linestyle = '-') # solid
plt.plot(x, -x - 1,linestyle = '--') # dashed
plt.plot(x, -x - 2,linestyle = '-.') # dashdot
plt.plot(x, -x - 3,linestyle = ':'); # dotted
plt.plot(x, -x - 4,linestyle = '',marker = 'x'); # only marker

# %% [markdown]
# ***
# ## Parametrized Linestyle
# ***

# %%
plt.figure(figsize = [10,9])
plt.plot(x, x,linestyle = (0,(1,10)),label = 'loosely dotted') 
plt.plot(x, x + 0.5,linestyle = (0,(1,5)),label = 'dotted')
plt.plot(x, x + 1,linestyle = (0,(1,1)),label = 'densely dotted')
plt.plot(x, x + 1.5,linestyle = (5,(10,3)),label = 'long dash with offset')
plt.plot(x, x + 2,linestyle = (0,(5,10)),label = 'loosely dashed')
plt.plot(x, x + 2.5,linestyle = (0,(5,5)),label = 'dashed')
plt.plot(x, x + 3,linestyle = (0,(5,1)),label = 'densely dashed')
plt.plot(x, x + 3.5,linestyle = (0,(3,10,1,10)),label = 'loosely dashdotted')
plt.plot(x, x + 4,linestyle = (0,(3,5,1,5)),label = 'dashdotted')
plt.plot(x, x + 4.5,linestyle = (0,(3,5,1,5,1,5)),label = 'dashdotdotted')
plt.plot(x, x + 5,linestyle = (0,(3,10,1,10,1,10)),label = 'loosely dashdotdotted')
plt.plot(x, x + 5.5,linestyle = (0,(3,1,1,1,1,1)),label = 'densely dashdotdotted')
plt.legend(loc = 'lower right')

# %%
# comb them
plt.plot(x, x + 0,color = 'green') # solid green
plt.plot(x, x + 1,color = 'cyan',linestyle = '--') # dashed cyan
plt.plot(x, x + 2,color = 'black',linestyle = '-.') # dashdot black
plt.plot(x, x + 3,color = 'red',linestyle = (0,(3,1,1,1,1,1))) # densely dashdotdotted red

# %% [markdown]
# ***
# ## Unfilled Marker
# ***

# %%
unfilled_markers = [m for m,func in Line2D.markers.items()
                    if func != 'nothing' 
                    and m not in Line2D.filled_markers]
plt.figure(figsize = [6,8])
plt.title('Unfilled Marker',fontsize = 20)
for k,marker in enumerate(unfilled_markers):
    plt.text(-0.5,k,f"marker = '{marker}'")
    plt.plot([k]*3,marker = marker,markersize = 12,linestyle = '--')
plt.axis('off')
# Out:
# (np.float64(-0.1), np.float64(2.1), np.float64(-1.0), np.float64(21.0))

# %% [markdown]
# ***
# ## Filled Marker
# ***

# %%
Line2D.filled_markers
plt.figure(figsize = [6,7])
plt.title('Filled Marker',fontsize = 20)
for k,marker in enumerate(Line2D.filled_markers):
    plt.text(-0.5,k,f"marker = '{marker}'")
    plt.plot([k]*3,marker = marker,markersize = 12,linestyle = '--')
plt.axis('off')
# Out:
# (np.float64(-0.1), np.float64(2.1), np.float64(-0.75), np.float64(15.75))

# %% [markdown]
# ***
# ## Marker fill styles
# ***

# %%
fig, ax = plt.subplots()
fig.suptitle('Marker fillstyle',fontsize = 14)
fig.subplots_adjust(left = 0.4)
filled_marker_style = dict(marker='o',linestyle=':',markersize=15,
                           color='darkgray',
                           markerfacecolor='xkcd:purple',
                           markerfacecoloralt='lime',
                           markeredgecolor='black')
for y, fill_style in enumerate(Line2D.fillStyles):
    ax.text(-0.5, y, repr(fill_style))
    ax.plot([y] * 3,fillstyle = fill_style,**filled_marker_style)
ax.axis('off')
# Out:
# (np.float64(-0.1), np.float64(2.1), np.float64(-0.25), np.float64(5.25))

# %% [markdown]
# ***
# ## Mathtext Markers
# ***

# %%
markers = ["$\mathbf{B}$",
           r"$\frac{1}{2}$",
           "$f$",
           "$\u266B$",
           r"$\mathcal{A}$"]
plt.figure()
for y,marker in enumerate(markers):
    plt.text(-0.5,y,repr(marker).replace("$", r"\$"))
    plt.plot([y] * 3,marker = marker,linestyle = 'dashed',markersize = 15)
    plt.axis('off')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/gv/755jwkvj1_7gncxqw4flsmch0000gn/T/ipykernel_62525/698247849.py:1: SyntaxWarning: invalid escape sequence '\m'
#   markers = ["$\mathbf{B}$",

# %% [markdown]
# ***
# ## Path Marker
# ***

# %%
star = mpath.Path.unit_regular_star(7)
circle = mpath.Path.unit_circle()
# concatenate the circle with an internal cutout of the star
cut_star = mpath.Path(
    vertices = np.concatenate([circle.vertices,star.vertices[::-1]]),
    codes = np.concatenate([circle.codes,star.codes]))
plt.figure()
plt.title('Path Markers')
markers = {'star':star,
           'circle':circle,
           'cut_star':cut_star}
for y,(name,marker) in enumerate(markers.items()):
    plt.text(-0.5,y,name)
    plt.plot([y]*3,marker = marker,linestyle = 'dashed',markersize = 15)
    plt.axis('off')

# %% [markdown]
# ***
# ## Rotation Marker
# ***

# %%
angles = [0,30,60,90,120,150]
plt.figure(figsize = [7,5])
plt.suptitle('Rotated markers',fontsize = 20)
case = {'Filled marker':'o',
        'Un-filled marker':'1',
        'Equation marker':r'$\frac{1}{x}$'}
for k,(name,marker) in enumerate(case.items()):
    plt.text(-0.5,k,name)
    for x,theta in enumerate(angles,start = 1):
        t = Affine2D().rotate_deg(theta)
        plt.plot(x,k,
                 marker = MarkerStyle(marker,'left',t),
                 color = 'red',markersize = 15)
for x, theta in enumerate(angles,start = 1):
    plt.text(x,2.5,f"{theta}°",horizontalalignment = "center")
plt.axis('off')
# Out:
# (np.float64(0.75), np.float64(6.25), np.float64(-0.1), np.float64(2.1))

# %% [markdown]
# ***
# ## Axes Limit Adjust
# ***

# %%
fig, ax = plt.subplots(2,ncols = 2,figsize = [9,6])
x = np.linspace(0,10,100)
# plot (0,0)
ax[(0,0)].set_title('Origin')
ax[(0,0)].plot(x,np.sin(x))
# plot (1,0)
ax[(1,0)].set_title('adjust the axes limit')
ax[(1,0)].plot(x,np.sin(x))
ax[(1,0)].set_xlim(-1,11)
ax[(1,0)].set_ylim(-1.5,1.5)
# plot (0,1)
ax[(0,1)].axis('off')
# plot (1,1)
ax[(1,1)].set_title('reverse the y-axis')
ax[(1,1)].plot(x,np.sin(x))
ax[(1,1)].set_xlim(10,0)
ax[(1,1)].set_ylim(1.2,-1.2)
# Out:
# (1.2, -1.2)

# %% [markdown]
# ***
# ## Labeling Plots
# ***

# %%
plt.plot(x,np.sin(x))
plt.title('Sine Wave')
plt.xlabel(r'$\theta$')
plt.ylabel(r'$\sin(\theta)$')
# Out:
# Text(0, 0.5, '$\\sin(\\theta)$')

# %%
# ccreate a plot legend that labels each line type.
plt.plot(x,np.sin(x),label = 'sine')
plt.plot(x,np.cos(x),label = 'cosine')
plt.axis('equal')
plt.legend()

# %%
# ax.set method
ax = plt.axes()
ax.plot(x,np.sin(x))
ax.set(xlim = (0,10),
       ylim = (-2,2),
       xlabel = 'x',ylabel = 'sin(x)',
       title = 'A Simple Plot');

# %% [markdown]
# ### Annotations

# %%
plt.figure()
f = lambda x:np.exp(-x**2 / 2)
x = np.arange(-3,3,1e-3)
plt.plot(x,f(x))
plt.annotate(r'maximum of $f(x)$',
             xy = (0,1),xytext = (1,1.2),
             arrowprops = dict(color = 'red',shrink = 0.05))
plt.ylim(0,1.5)
# Out:
# (0.0, 1.5)

# %% [markdown]
# ***
# ## Scatter Plot
# ***

# %%
x = np.linspace(0,10,30)
y = np.sin(x)
plt.scatter(x,y)

# %%
rng = np.random.default_rng(0)
x = rng.normal(size = 100)
y = rng.normal(size = 100)
colors = rng.random(100)
sizes = 1000 * rng.random(100)
plt.scatter(x,y,c = colors,s = sizes,alpha = 0.3)
plt.colorbar() # show color scale

# %%
from sklearn.datasets import load_iris
# each sample is ne of three types of flowers 
# that has had the size of its petals and sepals carefully measured
iris = load_iris()
features = iris.data.T
plt.scatter(features[0],features[1],
            alpha = 0.4,s = 100 * features[3],
            c = iris.target,cmap = 'viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# ***
# ## Errorbars
# ***

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x,y,yerr = dy,fmt = '.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x,y,yerr = dy,fmt = 'o',color = 'black',
             ecolor = 'lightgray',elinewidth = 3,capsize = 0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ***
# ## Continuous Error (Confidence Band)
# ***

# %%
N = 21
x = np.linspace(0,10,11)
y = [3.9,4.4,10.8,10.3,
     11.2,13.1,14.1,9.9,
     13.9,15.1,12.5]
# fit a linear curve an estimate its y-values and their error.
a,b = np.polyfit(x,y,deg = 1)
y_est = a * x + b
y_err = x.std() * np.sqrt(1/len(x) + (x - x.mean())**2 / np.sum((x - x.mean())**2))
fig, ax = plt.subplots()
ax.plot(x,y_est,'--',color = 'red')
ax.fill_between(x,y_est - y_err,y_est + y_err,alpha = 0.2,color = 'grey')
ax.plot(x,y,'o',color = 'black')

# %% [markdown]
# ***
# ## Contour Plot
# ***

# %%
f = lambda x,y:np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)
x = np.linspace(0,5,50)
y = np.linspace(0,5,40)
X,Y = np.meshgrid(x,y)
Z = f(X,Y)
# When single color is used
# neg value is dashed line
# pos value is solid line
plt.figure()
plt.contour(X,Y,Z,colors = 'black')
plt.colorbar()

# %%
# RdGy short for Red-Gray colormap
plt.contour(X,Y,Z,20,cmap = 'RdGy')

# %%
# For filled contour plots
plt.contourf(X,Y,Z,20,cmap = 'RdGy')
plt.colorbar()

# %% [markdown]
# ***
# ## Colormap
# ***

# %%
cmaps = [('Perceptually Uniform Sequential',
          ['viridis','plasma','inferno','magma','cividis']),
         ('Sequential',
          ['Greys','Purples','Blues','Greens','Oranges','Reds',
           'YlOrBr','YlOrRd','OrRd','PuRd','RdPu','BuPu','GnBu',
           'PuBu','YlGnBu','PuBuGn','BuGn','YlGn']),
         ('Sequential (2)',
          ['binary','gist_yarg','gist_gray','gray','bone','pink',
           'spring','summer','autumn','winter','cool','Wistia',
           'hot','afmhot','gist_heat','copper']),
         ('Diverging',
          ['PiYG','PRGn','BrBG','PuOr','RdGy','RdBu',
           'RdYlBu','RdYlGn','Spectral','coolwarm','bwr','seismic']),
         ('Cyclic',
          ['twilight', 'twilight_shifted', 'hsv']),
         ('Qualitative',
          ['Pastel1','Pastel2','Paired','Accent',
           'Dark2','Set1','Set2','Set3',
           'tab10','tab20','tab20b','tab20c']),
         ('Miscellaneous',
          ['flag','prism','ocean','gist_earth','terrain','gist_stern',
           'gnuplot','gnuplot2','CMRmap','cubehelix','brg','gist_rainbow',
           'rainbow','jet','turbo','nipy_spectral','gist_ncar'])]
gradient = np.linspace(0,1,256)
gradient = np.vstack((gradient,gradient))

def plot_color_gradients(cmap_category,cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows-1)*0.1)*0.22
    fig, axs = plt.subplots(nrows=nrows, figsize=(6.4, figh))
    fig.subplots_adjust(top=1-.35/figh, bottom=.15/figh, left=0.2, right=0.99)
    axs[0].set_title(f"{cmap_category} colormaps", fontsize=14)
    for ax, cmap_name in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=cmap_name)
        ax.text(-.01, .5, cmap_name, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)
    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()

for cmap_category, cmap_list in cmaps:
    plot_color_gradients(cmap_category, cmap_list)

# %% [markdown]
# ***
# ## Histograms
# ***

# %%
rng = np.random.default_rng(1701)
data = rng.normal(size=1000)
plt.hist(data)
# Out:
# (array([  6.,  17.,  71., 170., 245., 246., 157.,  67.,  17.,   4.]),
#  array([-3.26668015, -2.60694432, -1.94720849, -1.28747266, -0.62773683,
#          0.031999  ,  0.69173484,  1.35147067,  2.0112065 ,  2.67094233,
#          3.33067816]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data,bins = 30,density = True,alpha = 0.5,
         histtype = 'stepfilled',color = 'steelblue',
         edgecolor = 'none');

# %%
# Overplotting multiple histograms
x1 = rng.normal(0,0.8,1000)
x2 = rng.normal(-2,1,1000)
x3 = rng.normal(3,2,1000)
kwargs = dict(histtype = 'stepfilled',alpha = 0.3,density = True,bins = 40)
plt.hist(x1,**kwargs)
plt.hist(x2,**kwargs)
plt.hist(x3,**kwargs)
# Out:
# (array([0.00665794, 0.00332897, 0.00332897, 0.        , 0.00998691,
#         0.00332897, 0.03661865, 0.00998691, 0.04660556, 0.04993453,
#         0.07323731, 0.06990834, 0.08322421, 0.10985596, 0.13315874,
#         0.20639605, 0.14980359, 0.15313255, 0.1697774 , 0.18975121,
#         0.22636986, 0.15979049, 0.17310637, 0.22969883, 0.13981668,
#         0.16644843, 0.13315874, 0.14647462, 0.10319803, 0.08322421,
#         0.05659247, 0.07656628, 0.02996072, 0.03328969, 0.01997381,
#         0.02330278, 0.00665794, 0.00332897, 0.        , 0.00998691]),
#  array([-3.18468906, -2.88429572, -2.58390237, -2.28350903, -1.98311569,
#         -1.68272234, -1.382329  , -1.08193566, -0.78154231, -0.48114897,
#         -0.18075563,  0.11963771,  0.42003106,  0.7204244 ,  1.02081774,
#          1.32121109,  1.62160443,  1.92199777,  2.22239112,  2.52278446,
#          2.8231778 ,  3.12357115,  3.42396449,  3.72435783,  4.02475118,
# ...

# %%
mean = [0,0]
cov = [[1,1],[1,2]]
x,y = rng.multivariate_normal(mean,cov,10000).T
plt.hist2d(x, y, bins=30)
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
plt.hexbin(x, y, gridsize=30)
cb = plt.colorbar(label='count in bin')

# %% [markdown]
# ***
# ## 3D Points and Lines
# ***

# %%
fig = plt.figure(figsize = [10,8])
ax = plt.axes(projection='3d')
# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline,yline,zline,'gray')
# Data for three-dimensional scattered points
zd = 15 * np.random.random(100)
xd = np.sin(zd) + 0.1 * np.random.randn(100)
yd = np.cos(zd) + 0.1 * np.random.randn(100)
ax.scatter3D(xd,yd,zd,c = zd, cmap='Greens')

# %% [markdown]
# ***
# ## 3D Contour
# ***

# %%
f = lambda x,y:x**4 + y**4 - 4*x*y + 1
x = np.linspace(-2,2,100)
y = np.linspace(-2,2,100)
X,Y = np.meshgrid(x,y)
Z = f(X,Y)
fig = plt.figure(figsize = [10,8])
ax = plt.axes(projection='3d')
# Sometimes the default viewing angle is not optimal (80 is for countour level)
ax.contour3D(X,Y,Z,200,colors='crimson')
ax.set_zlim(-4,2)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
# Elevation 60 degree and azimuth 35 degree
ax.view_init(25,45)
fig

# %% [markdown]
# ## Surface plot
# ***

# %%
fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection='3d')

# 4. Use plot_surface for the solid look
# 'cmap' sets the color (Reds matches your image)
# 'antialiased=True' makes it look smooth
surf = ax.plot_surface(X,Y,Z,cmap='hot', edgecolor='none',antialiased = True)
# 5. Adjust the limits to "crop" the underwear properly
ax.set_zlim(-4,2)
# Out:
# (-4.0, 2.0)

# %% [markdown]
# ***
# ## Seaborn
# ***

# %% [markdown]
# ### Histgrams, KDE, Densities

# %%
mv = [0,0]
covm = [[5, 2],
		[2, 2]]
data = np.random.multivariate_normal(mv,covm,size = 2000)
data = pd.DataFrame(data, columns=['x','y'])
for col in 'xy':
	plt.hist(data[col], density=True, alpha=0.5)

# %%
sns.kdeplot(data = data,shade = True)
# Out:
# /var/folders/gv/755jwkvj1_7gncxqw4flsmch0000gn/T/ipykernel_62525/3770282478.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = data,shade = True)
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data = data,x = 'x',y = 'y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ***
# ## PairPlot
# ***

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue = 'species',height = 2.5)

# %% [markdown]
# ***
# ## Faceted Histograms
# ***

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']
grid = sns.FacetGrid(tips,row = "sex",col = "time",margin_titles = True)
grid.map(plt.hist,"tip_pct",bins = np.linspace(0,40,15))

# %% [markdown]
# ***
# ## Categorical Plots
# ***

# %%
g = sns.catplot(x = "day",y = "total_bill",hue = "sex",data = tips,kind = "box")
g.set_axis_labels("Day","Total Bill")

# %% [markdown]
# ***
# ## Joint Distribution
# ***

# %%
sns.jointplot(x = "total_bill",y = "tip",data = tips,kind = 'hex')

# %%
sns.jointplot(x = "total_bill",y = "tip",data = tips,kind = 'reg')

# %% [markdown]
# ***
# ## Bar Plots
# ***

# %%
planets = sns.load_dataset('planets')
planets.head()
g = sns.catplot(x = "year",data = planets,aspect = 2,
                kind = "count",color = 'steelblue')
g.set_xticklabels(step = 5)

# %%
g = sns.catplot(x = "year",data = planets,aspect = 4.0,
                kind = 'count',hue = 'method',order = range(2008, 2015))
g.set_ylabels('Number of Planets Discovered')
